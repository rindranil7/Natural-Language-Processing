# %% [markdown]
# # demonstrate coca

# %%
from PIL import Image
img = Image.open(r'D:/Downloads/COCA.png')
img1 = Image.open(r'D:/Downloads/COCA2.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1487x457 at 0x1E00229EA08>

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1488x834 at 0x1E00232D548>
